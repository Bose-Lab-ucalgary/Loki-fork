# %%
import os
import numpy as np
import pandas as pd
import torch

# local imports
from run_surv import getPValue_Binary, run_case

# %% [markdown]
# ## Train the model.
# Evaluate the performance with a 5-fold validation method. In the end, plot the survival curves of high-risk and low-risk groups using 50-50 and 30-70 quantile split.

# %%
cancer_type = 'lgg'
seed = 2024

run_case(case=cancer_type, seed=seed)
# Out:
# (0, 0) : 0
# (0, 1) : 1
# (1, 0) : 2
# (1, 1) : 3
# (2, 0) : 4
# (2, 1) : 5
# (3, 0) : 6
# (3, 1) : 7
# training: 389, validation: 98
# {'task_type': 'survival', 'mode': 'coattn', 'alpha_surv': 0.1, 'bag_loss': 'nll_surv', 'reg_type': 'omic', 'lambda_reg': 1e-05, 'gc': 32, 'n_classes': 4, 'fusion': 'concat', 'opt': 'adam', 'batch_size': 1, 'dropout': 0.25, 'lr': 0.002, 'reg': 1e-05, 'testing': False, 'weighted_sample': True, 'early_stopping': False, 'max_epochs': 20, 'results_dir': 'results_all_patches/5foldcv/tcga_lgg_cosine_s2024'}
#
# Training Fold 0!
#
# Init train/val/test splits... Training on 389 samples
# Validating on 98 samples
#
# Init loss function... 0.1
# Done!
#
# Init Model... Done!
# cos_Surv(
#   (mm): Sequential(
#     (0): Linear(in_features=1536, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=768, bias=True)
#     (3): ReLU()
#   )
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
# )
# ...
